# %% [markdown]
# # LSTM for new type of datasets

# %%
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn

import pandas as pd
import numpy as np

import plotly.express as px
from torch.optim import Adam


import matplotlib.pyplot as plt

# %% [markdown]
# ## Classes

# %%
class SequentDataset(Dataset):
    def __init__(self, dataframe: pd.DataFrame, n_dots=1, n_dot_parameters=7):
        self.n_dot_parameters = n_dot_parameters
        self.n_dots = n_dots
        self.X_, self.y_ = self.__make_stack(dataframe)
        # print(self.X_.shape)
        # print(self.y_.shape)

    def __len__(self):
        return len(self.X_)

    def __getitem__(self, idx):
        return self.X_[idx], self.y_[idx]

    def __make_stack(self, df: pd.DataFrame):
        seq_amount = df.shape[0] - 2 * self.n_dots - 1
        X = torch.zeros((seq_amount, self.n_dots, self.n_dot_parameters), dtype=torch.float32)
        y = torch.zeros((seq_amount, self.n_dots, self.n_dot_parameters), dtype=torch.float32)
        for i in range(seq_amount):
            X[i, :, :] = torch.reshape(torch.tensor(df.values[i:i+self.n_dots, :], dtype=torch.float32), (1, self.n_dots, self.n_dot_parameters))
            y[i, :, :] = torch.reshape(torch.tensor(df.values[i+1:i+1+self.n_dots, :], dtype=torch.float32), (1, self.n_dots, self.n_dot_parameters))

        # stacks = [[df.iloc[:-self.n_dots]]] + [df.iloc[i:].values if (self.n_dots == i) else df.iloc[i:-(self.n_dots - i)].values for i in range(1, self.n_dots + 1)]
        return (X, y)

# %%
# # sts
# class SequentDataset(Dataset):
#     def __init__(self, dataframe: pd.DataFrame, n_dots=1, n_dot_parameters=4):
#         self.n_dot_parameters = n_dot_parameters
#         self.n_dots = n_dots
#         self.X_, self.y_ = self.__make_stack(dataframe)
#         # print(self.X_.shape)
#         # print(self.y_.shape)

#     def __len__(self):
#         return len(self.X_)

#     def __getitem__(self, idx):
#         return self.X_[idx], self.y_[idx]

#     def __make_stack(self, df: pd.DataFrame):
#         seq_amount = df.shape[0] - 2 * self.n_dots - 1
#         X = torch.zeros((seq_amount, self.n_dots, self.n_dot_parameters), dtype=torch.float32)
#         y = torch.zeros((seq_amount, self.n_dots, self.n_dot_parameters), dtype=torch.float32)
#         for i in range(seq_amount):  
#             X[i, :, :] = torch.reshape(torch.tensor(df.values[i:i+self.n_dots, :], dtype=torch.float32), (1, self.n_dots, self.n_dot_parameters))
#             y[i, :, :] = torch.reshape(torch.tensor(df.values[i+self.n_dots : i+2*self.n_dots, :], dtype=torch.float32), (1, self.n_dots, self.n_dot_parameters))
            

#         # stacks = [[df.iloc[:-self.n_dots]]] + [df.iloc[i:].values if (self.n_dots == i) else df.iloc[i:-(self.n_dots - i)].values for i in range(1, self.n_dots + 1)]
#         return (X, y)

# %%
class RNNModel(nn.Module):
    def __init__(self, input_size=7, hidden_layer_size=100, output_size=7, num_layers=10):
        super(RNNModel, self).__init__()
        self.hidden_layer_size = hidden_layer_size
        self.num_layers = num_layers

        # Define the LSTM layer
        self.rnn = nn.RNN(input_size, hidden_layer_size, num_layers, batch_first=True)

        # Define the output layer
        self.linear = nn.Linear(hidden_layer_size, output_size)

    def forward(self, x):
        # x = x.to(device)
        batch_size = x.size(0)
        self.h = torch.zeros(self.num_layers, batch_size, self.hidden_layer_size).requires_grad_()
        self.h = self.h
        out, _ = self.rnn(x, self.h)

        # print(out.size())

        # Pass through fully connected layer
        out = self.linear(out)  # We want the output corresponding to the last time step
        return out

# %%
N_DOTS = 25
BATCH_SIZE = 1
N_DOT_PARAMETERS = 7
N_LSTM_LAYERS = 1

# %%
trajectory_train = pd.read_csv("../../sets_for_article/parab_train.csv")
trajectory_test = pd.read_csv("../../sets_for_article/parab_test.csv")

trajectory_train['t'] = 1
trajectory_test['t'] = 1

# %%
fig = px.line_3d(trajectory_train, x="X", y="Y", z="Z", color='I')
fig.show()

# %%
train = SequentDataset(trajectory_train[['t','X','Y','Z','Vx','Vy','Vz']][:8000], N_DOTS, N_DOT_PARAMETERS)
test = SequentDataset(trajectory_train[['t','X','Y','Z','Vx','Vy','Vz']][8000:], N_DOTS, N_DOT_PARAMETERS)
test2 = SequentDataset(trajectory_test[['t','X','Y','Z','Vx','Vy','Vz']], N_DOTS, N_DOT_PARAMETERS)

# %%
model = RNNModel(input_size=N_DOT_PARAMETERS, num_layers=N_LSTM_LAYERS)
# loss_model = nn.L1Loss()
# loss_model = nn.HuberLoss()
loss_model = nn.MSELoss()
# opt = Adam(model.parameters(), lr=0.005)
# lr_scheduler = torch.optim.lr_scheduler.StepLR(opt, step_size=5, gamma=0.5)

# %%
opt = Adam(model.parameters(), lr=0.0001)
lr_scheduler = torch.optim.lr_scheduler.StepLR(opt, step_size=25, gamma=0.5)

# %%
# model.load_state_dict(torch.load("lstm_dach_28_10.pt"))

# %%
def train_model(model, criterion, optimizer, train_loader, device):
    model.train()
    train_loss = []

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
    
        optimizer.zero_grad()
        outputs = model(inputs)

        loss = criterion(outputs, targets)
        train_loss.append(loss.item())

        loss.backward()
        optimizer.step()
    
    return sum(train_loss)/len(train_loss)

# %%
def evaluate_model(model, criterion, test_loader, device):
    model.eval()
    val_loss = []
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss.append(loss.item())
    return sum(val_loss)/len(val_loss)

# %%
EPOCH = 150
train_losses = []
val_losses = []

train_data, val_data = random_split(train,[0.8,0.2])

train_loader = DataLoader(train, batch_size=8, shuffle=True)
val_loader = DataLoader(test, batch_size=8, shuffle=False)

for epoch in range(EPOCH):

    mean_train_loss = train_model(model, loss_model, opt, train_loader, "cpu")

    train_losses.append(mean_train_loss)

    mean_val_loss = evaluate_model(model, loss_model, val_loader, "cpu")

    val_losses.append(mean_val_loss)

    lr_scheduler.step()
    lr = lr_scheduler.get_last_lr()

    print(f"Epoch [{epoch+1}/{EPOCH}], train_loss = {mean_train_loss:.6f}, val_loss = {mean_val_loss:.6f}, lr = {lr}")
# Out:
# Epoch [1/150], train_loss = 1682.353460, val_loss = 4135.197760, lr = [0.0001]
# Epoch [2/150], train_loss = 1333.492056, val_loss = 3534.035308, lr = [0.0001]
# Epoch [3/150], train_loss = 1060.171332, val_loss = 3005.086738, lr = [0.0001]
# Epoch [4/150], train_loss = 833.905478, val_loss = 2534.665314, lr = [0.0001]
# Epoch [5/150], train_loss = 646.040881, val_loss = 2116.519760, lr = [0.0001]
# Epoch [6/150], train_loss = 492.049219, val_loss = 1747.367356, lr = [0.0001]
# Epoch [7/150], train_loss = 367.099019, val_loss = 1422.722325, lr = [0.0001]
# Epoch [8/150], train_loss = 267.721070, val_loss = 1144.171036, lr = [0.0001]
# Epoch [9/150], train_loss = 190.423864, val_loss = 906.932166, lr = [0.0001]
# Epoch [10/150], train_loss = 131.158596, val_loss = 705.877012, lr = [0.0001]
# Epoch [11/150], train_loss = 87.092035, val_loss = 541.246789, lr = [0.0001]
# Epoch [12/150], train_loss = 55.350931, val_loss = 409.172155, lr = [0.0001]
# Epoch [13/150], train_loss = 33.429734, val_loss = 305.928917, lr = [0.0001]
# Epoch [14/150], train_loss = 18.973485, val_loss = 227.116195, lr = [0.0001]
# Epoch [15/150], train_loss = 10.085041, val_loss = 168.328669, lr = [0.0001]
# Epoch [16/150], train_loss = 4.974546, val_loss = 124.551244, lr = [0.0001]
# Epoch [17/150], train_loss = 2.317367, val_loss = 92.823514, lr = [0.0001]
# Epoch [18/150], train_loss = 1.066405, val_loss = 71.027297, lr = [0.0001]
# Epoch [19/150], train_loss = 0.522938, val_loss = 55.908042, lr = [0.0001]
# Epoch [20/150], train_loss = 0.291014, val_loss = 45.829122, lr = [0.0001]
# Epoch [21/150], train_loss = 0.182970, val_loss = 38.948556, lr = [0.0001]
# Epoch [22/150], train_loss = 0.123115, val_loss = 34.340944, lr = [0.0001]
# Epoch [23/150], train_loss = 0.084285, val_loss = 30.949426, lr = [0.0001]
# Epoch [24/150], train_loss = 0.057465, val_loss = 28.329445, lr = [0.0001]
# Epoch [25/150], train_loss = 0.041134, val_loss = 26.150964, lr = [5e-05]
# Epoch [26/150], train_loss = 0.029146, val_loss = 25.432937, lr = [5e-05]
# Epoch [27/150], train_loss = 0.024212, val_loss = 24.509191, lr = [5e-05]
# Epoch [28/150], train_loss = 0.020140, val_loss = 23.649872, lr = [5e-05]
# Epoch [29/150], train_loss = 0.016497, val_loss = 22.862597, lr = [5e-05]
# Epoch [30/150], train_loss = 0.013549, val_loss = 22.187444, lr = [5e-05]
# Epoch [31/150], train_loss = 0.011213, val_loss = 21.591202, lr = [5e-05]
# Epoch [32/150], train_loss = 0.008923, val_loss = 21.041345, lr = [5e-05]
# Epoch [33/150], train_loss = 0.007420, val_loss = 20.489174, lr = [5e-05]
# Epoch [34/150], train_loss = 0.006146, val_loss = 20.083256, lr = [5e-05]
# Epoch [35/150], train_loss = 0.005111, val_loss = 19.656919, lr = [5e-05]
# Epoch [36/150], train_loss = 0.004252, val_loss = 19.281999, lr = [5e-05]
# Epoch [37/150], train_loss = 0.003658, val_loss = 18.905709, lr = [5e-05]
# Epoch [38/150], train_loss = 0.003171, val_loss = 18.545676, lr = [5e-05]
# Epoch [39/150], train_loss = 0.002906, val_loss = 18.186547, lr = [5e-05]
# Epoch [40/150], train_loss = 0.002694, val_loss = 17.925118, lr = [5e-05]
# Epoch [41/150], train_loss = 0.002279, val_loss = 17.668843, lr = [5e-05]
# Epoch [42/150], train_loss = 0.002114, val_loss = 17.373367, lr = [5e-05]
# Epoch [43/150], train_loss = 0.001948, val_loss = 17.126806, lr = [5e-05]
# Epoch [44/150], train_loss = 0.001972, val_loss = 16.926241, lr = [5e-05]
# Epoch [45/150], train_loss = 0.001806, val_loss = 16.683919, lr = [5e-05]
# Epoch [46/150], train_loss = 0.001560, val_loss = 16.536119, lr = [5e-05]
# Epoch [47/150], train_loss = 0.001444, val_loss = 16.329026, lr = [5e-05]
# Epoch [48/150], train_loss = 0.001372, val_loss = 16.143575, lr = [5e-05]
# Epoch [49/150], train_loss = 0.001499, val_loss = 15.988416, lr = [5e-05]
# Epoch [50/150], train_loss = 0.001172, val_loss = 15.867548, lr = [2.5e-05]
# Epoch [51/150], train_loss = 0.000982, val_loss = 15.771137, lr = [2.5e-05]
# Epoch [52/150], train_loss = 0.000954, val_loss = 15.676418, lr = [2.5e-05]
# Epoch [53/150], train_loss = 0.000935, val_loss = 15.573386, lr = [2.5e-05]
# Epoch [54/150], train_loss = 0.000893, val_loss = 15.463315, lr = [2.5e-05]
# Epoch [55/150], train_loss = 0.000849, val_loss = 15.379069, lr = [2.5e-05]
# Epoch [56/150], train_loss = 0.000870, val_loss = 15.294241, lr = [2.5e-05]
# Epoch [57/150], train_loss = 0.000776, val_loss = 15.223030, lr = [2.5e-05]
# Epoch [58/150], train_loss = 0.000749, val_loss = 15.119642, lr = [2.5e-05]
# Epoch [59/150], train_loss = 0.000748, val_loss = 15.040871, lr = [2.5e-05]
# Epoch [60/150], train_loss = 0.000724, val_loss = 14.971274, lr = [2.5e-05]
# Epoch [61/150], train_loss = 0.000730, val_loss = 14.899992, lr = [2.5e-05]
# Epoch [62/150], train_loss = 0.000690, val_loss = 14.851721, lr = [2.5e-05]
# Epoch [63/150], train_loss = 0.000641, val_loss = 14.782740, lr = [2.5e-05]
# Epoch [64/150], train_loss = 0.000627, val_loss = 14.715463, lr = [2.5e-05]
# Epoch [65/150], train_loss = 0.000596, val_loss = 14.664722, lr = [2.5e-05]
# Epoch [66/150], train_loss = 0.000611, val_loss = 14.586933, lr = [2.5e-05]
# Epoch [67/150], train_loss = 0.000552, val_loss = 14.527038, lr = [2.5e-05]
# Epoch [68/150], train_loss = 0.000592, val_loss = 14.482296, lr = [2.5e-05]
# Epoch [69/150], train_loss = 0.000530, val_loss = 14.415017, lr = [2.5e-05]
# Epoch [70/150], train_loss = 0.000569, val_loss = 14.368988, lr = [2.5e-05]
# Epoch [71/150], train_loss = 0.000481, val_loss = 14.314657, lr = [2.5e-05]
# Epoch [72/150], train_loss = 0.000509, val_loss = 14.265521, lr = [2.5e-05]
# Epoch [73/150], train_loss = 0.000479, val_loss = 14.215766, lr = [2.5e-05]
# Epoch [74/150], train_loss = 0.000477, val_loss = 14.167805, lr = [2.5e-05]
# Epoch [75/150], train_loss = 0.000498, val_loss = 14.119348, lr = [1.25e-05]
# Epoch [76/150], train_loss = 0.000379, val_loss = 14.087133, lr = [1.25e-05]
# Epoch [77/150], train_loss = 0.000394, val_loss = 14.060646, lr = [1.25e-05]
# Epoch [78/150], train_loss = 0.000383, val_loss = 14.032184, lr = [1.25e-05]
# Epoch [79/150], train_loss = 0.000370, val_loss = 13.994327, lr = [1.25e-05]
# Epoch [80/150], train_loss = 0.000371, val_loss = 13.964481, lr = [1.25e-05]
# Epoch [81/150], train_loss = 0.000363, val_loss = 13.928652, lr = [1.25e-05]
# Epoch [82/150], train_loss = 0.000352, val_loss = 13.887830, lr = [1.25e-05]
# Epoch [83/150], train_loss = 0.000343, val_loss = 13.862729, lr = [1.25e-05]
# Epoch [84/150], train_loss = 0.000343, val_loss = 13.836461, lr = [1.25e-05]
# Epoch [85/150], train_loss = 0.000343, val_loss = 13.796891, lr = [1.25e-05]
# Epoch [86/150], train_loss = 0.000325, val_loss = 13.770695, lr = [1.25e-05]
# Epoch [87/150], train_loss = 0.000334, val_loss = 13.744457, lr = [1.25e-05]
# Epoch [88/150], train_loss = 0.000317, val_loss = 13.711155, lr = [1.25e-05]
# Epoch [89/150], train_loss = 0.000309, val_loss = 13.683702, lr = [1.25e-05]
# Epoch [90/150], train_loss = 0.000302, val_loss = 13.660158, lr = [1.25e-05]
# Epoch [91/150], train_loss = 0.000296, val_loss = 13.622567, lr = [1.25e-05]
# Epoch [92/150], train_loss = 0.000303, val_loss = 13.597786, lr = [1.25e-05]
# Epoch [93/150], train_loss = 0.000296, val_loss = 13.574837, lr = [1.25e-05]
# Epoch [94/150], train_loss = 0.000281, val_loss = 13.547182, lr = [1.25e-05]
# Epoch [95/150], train_loss = 0.000284, val_loss = 13.517778, lr = [1.25e-05]
# Epoch [96/150], train_loss = 0.000273, val_loss = 13.498602, lr = [1.25e-05]
# Epoch [97/150], train_loss = 0.000274, val_loss = 13.469327, lr = [1.25e-05]
# Epoch [98/150], train_loss = 0.000265, val_loss = 13.442329, lr = [1.25e-05]
# Epoch [99/150], train_loss = 0.000264, val_loss = 13.414491, lr = [1.25e-05]
# Epoch [100/150], train_loss = 0.000259, val_loss = 13.391974, lr = [6.25e-06]
# Epoch [101/150], train_loss = 0.000233, val_loss = 13.378320, lr = [6.25e-06]
# Epoch [102/150], train_loss = 0.000234, val_loss = 13.364918, lr = [6.25e-06]
# Epoch [103/150], train_loss = 0.000230, val_loss = 13.342772, lr = [6.25e-06]
# Epoch [104/150], train_loss = 0.000231, val_loss = 13.327156, lr = [6.25e-06]
# Epoch [105/150], train_loss = 0.000225, val_loss = 13.306979, lr = [6.25e-06]
# Epoch [106/150], train_loss = 0.000224, val_loss = 13.291279, lr = [6.25e-06]
# Epoch [107/150], train_loss = 0.000221, val_loss = 13.278282, lr = [6.25e-06]
# Epoch [108/150], train_loss = 0.000220, val_loss = 13.259815, lr = [6.25e-06]
# Epoch [109/150], train_loss = 0.000215, val_loss = 13.241825, lr = [6.25e-06]
# Epoch [110/150], train_loss = 0.000213, val_loss = 13.225653, lr = [6.25e-06]
# Epoch [111/150], train_loss = 0.000210, val_loss = 13.208005, lr = [6.25e-06]
# Epoch [112/150], train_loss = 0.000211, val_loss = 13.191201, lr = [6.25e-06]
# Epoch [113/150], train_loss = 0.000208, val_loss = 13.176910, lr = [6.25e-06]
# Epoch [114/150], train_loss = 0.000203, val_loss = 13.161388, lr = [6.25e-06]
# Epoch [115/150], train_loss = 0.000203, val_loss = 13.147433, lr = [6.25e-06]
# Epoch [116/150], train_loss = 0.000198, val_loss = 13.132357, lr = [6.25e-06]
# Epoch [117/150], train_loss = 0.000199, val_loss = 13.113960, lr = [6.25e-06]
# Epoch [118/150], train_loss = 0.000194, val_loss = 13.100581, lr = [6.25e-06]
# Epoch [119/150], train_loss = 0.000193, val_loss = 13.085447, lr = [6.25e-06]
# Epoch [120/150], train_loss = 0.000191, val_loss = 13.076166, lr = [6.25e-06]
# Epoch [121/150], train_loss = 0.000190, val_loss = 13.057719, lr = [6.25e-06]
# Epoch [122/150], train_loss = 0.000188, val_loss = 13.040965, lr = [6.25e-06]
# Epoch [123/150], train_loss = 0.000184, val_loss = 13.025680, lr = [6.25e-06]
# Epoch [124/150], train_loss = 0.000183, val_loss = 13.008249, lr = [6.25e-06]
# Epoch [125/150], train_loss = 0.000181, val_loss = 12.992862, lr = [3.125e-06]
# Epoch [126/150], train_loss = 0.000174, val_loss = 12.990348, lr = [3.125e-06]
# Epoch [127/150], train_loss = 0.000173, val_loss = 12.982412, lr = [3.125e-06]
# Epoch [128/150], train_loss = 0.000172, val_loss = 12.973732, lr = [3.125e-06]
# Epoch [129/150], train_loss = 0.000171, val_loss = 12.966307, lr = [3.125e-06]
# Epoch [130/150], train_loss = 0.000170, val_loss = 12.952894, lr = [3.125e-06]
# Epoch [131/150], train_loss = 0.000169, val_loss = 12.947763, lr = [3.125e-06]
# Epoch [132/150], train_loss = 0.000168, val_loss = 12.938827, lr = [3.125e-06]
# Epoch [133/150], train_loss = 0.000167, val_loss = 12.929268, lr = [3.125e-06]
# Epoch [134/150], train_loss = 0.000166, val_loss = 12.921553, lr = [3.125e-06]
# Epoch [135/150], train_loss = 0.000165, val_loss = 12.913314, lr = [3.125e-06]
# Epoch [136/150], train_loss = 0.000163, val_loss = 12.904864, lr = [3.125e-06]
# Epoch [137/150], train_loss = 0.000163, val_loss = 12.896851, lr = [3.125e-06]
# Epoch [138/150], train_loss = 0.000161, val_loss = 12.887684, lr = [3.125e-06]
# Epoch [139/150], train_loss = 0.000160, val_loss = 12.876782, lr = [3.125e-06]
# Epoch [140/150], train_loss = 0.000159, val_loss = 12.870528, lr = [3.125e-06]
# Epoch [141/150], train_loss = 0.000158, val_loss = 12.861262, lr = [3.125e-06]
# Epoch [142/150], train_loss = 0.000157, val_loss = 12.853289, lr = [3.125e-06]
# Epoch [143/150], train_loss = 0.000156, val_loss = 12.845305, lr = [3.125e-06]
# Epoch [144/150], train_loss = 0.000155, val_loss = 12.835285, lr = [3.125e-06]
# Epoch [145/150], train_loss = 0.000154, val_loss = 12.830459, lr = [3.125e-06]
# Epoch [146/150], train_loss = 0.000153, val_loss = 12.821674, lr = [3.125e-06]
# Epoch [147/150], train_loss = 0.000152, val_loss = 12.811521, lr = [3.125e-06]
# Epoch [148/150], train_loss = 0.000152, val_loss = 12.805118, lr = [3.125e-06]
# Epoch [149/150], train_loss = 0.000150, val_loss = 12.796898, lr = [3.125e-06]
# Epoch [150/150], train_loss = 0.000149, val_loss = 12.787522, lr = [1.5625e-06]

# %%
# torch.save(model.state_dict(),"rnn_dach_31_10.pt")

# %%
plt.plot(train_losses, '-b')
plt.plot(val_losses, '-r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
predictions = []
true = []

start, _ = test[0]
start = torch.reshape(start, (1,N_DOTS,N_DOT_PARAMETERS))

for i in range(1000):
    with torch.no_grad():
        pred = model(start)
        predictions.append(pred[0, -1, :])
        start[0, :-1, :] = start.clone()[0, 1:, :]
        start[0, -1, :] = pred[0, -1, :]
        # start = pred
_, y_true  = test[:1000]
_, last = train[:]

# %%
# # sts
# predictions = []
# true = []

# start, _ = test[0]
# start = torch.reshape(start, (1,N_DOTS,N_DOT_PARAMETERS))

# for i in range(1000):
#     with torch.no_grad():
#         pred = model(start)
#         predictions.append(pred[0, -1, :])
#         start = pred
#         # start = pred
# _, y_true  = test[:1000]
# _, last = train[:]

# %%
pred_data = pd.DataFrame([[0,0,0,0,0,0,0,0]], columns=["Time", "X", "Y", "Z","Vx","Vy","Vz","I"])

p_x = pd.DataFrame(np.vstack(list(map(lambda x: x.detach().numpy(), predictions))), columns=["Time", "X", "Y", "Z","Vx","Vy","Vz"])
p_x['I'] = "Predict"
_, y  = test[:]
p_y = pd.DataFrame(y.detach().numpy()[:, 0, :], columns=["Time", "X", "Y", "Z","Vx","Vy","Vz"])
p_y['I'] = "True"
p_last = pd.DataFrame(last.detach().numpy()[:, 0, :], columns=["Time", "X", "Y", "Z","Vx","Vy","Vz"])
p_last["I"] = "Last"

pred_data = pd.concat([pred_data,p_x,p_y,p_last],axis=0)


aaaab = pred_data.drop(pred_data.index[0], inplace=False)

# %%
fig = px.line_3d(aaaab, x="X", y="Y", z="Z", color='I',markers=0)
fig.show()
